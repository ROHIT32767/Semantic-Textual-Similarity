# %% [markdown]
# <h1> Doc2Vec embeddings </h1>
# <p>Doc2Vec model is trained to generate representative embeddings of sentences and with these embeddings following approaches are applied to generate STS scores:</p>
# <li>Normalized cosine similarity score </li>
# <li>BiLSTM Regression neural network model</li>
# <li>BiGRU Regression neural network model</li>

# %%
import pandas as pd
import numpy as np
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from scipy import spatial
from scipy.stats import pearsonr
import torch
import torch.nn as nn
import torch.utils.data as data
from sklearn.linear_model import LinearRegression
import logging
import warnings
import sys

logging.disable(logging.WARNING)
warnings.filterwarnings('ignore')
np.set_printoptions(threshold=sys.maxsize)

# %%
def pearson_corr(y_true, y_pred):
    corr, _ = pearsonr(y_true, y_pred)
    return corr

# %% [markdown]
# ## Mono-Lingual Semantic Similarity

# %%
train_data = pd.read_csv('../utils2/data/train.csv')
val_data = pd.read_csv('../utils2/data/val.csv')
test_data = pd.read_csv('../utils2/data/test.csv')

train_data['s1'] = train_data['s1'].apply(eval)
train_data['s2'] = train_data['s2'].apply(eval)
val_data['s1'] = val_data['s1'].apply(eval)
val_data['s2'] = val_data['s2'].apply(eval)
test_data['s1'] = test_data['s1'].apply(eval)
test_data['s2'] = test_data['s2'].apply(eval)

# %%
total_sents_unk = list(train_data['s1'])
total_sents_unk.extend(list(train_data['s2']))
total_sents_unk
# Out:
# [['sudan', 'block', 'youtub', 'antiislam', 'film'],
#  ['man', 'ride', 'white', 'hors'],
#  ['mr',
#   'mors',
#   'charg',
#   'assault',
#   'mr',
#   'darvish',
#   'charg',
#   'file',
#   'fals',
#   'report'],
#  ['girl', 'play', 'pile', 'color', 'ball'],
#  ['person', 'black', 'jacket', 'trick', 'motorbik'],
#  ['man', 'woman', 'drive', 'street', 'jeep'],
#  ['girl', 'ride', 'hors'],
#  ['man', 'elegantli', 'dress', 'black', 'wear', 'elabor', 'black', 'mask'],
#  ['woman', 'snowboard', 'rail', 'snow'],
#  ['cluster', 'four', 'brown', 'dog', 'play', 'field', 'brown', 'grass'],
#  ['two', 'men', 'talk'],
#  ['urg',
#   'patienc',
#   'american',
#   'eager',
#   'servic',
#   'intend',
#   'block',
#   'num',
#   'percent',
#   'telemarket',
#   'call'],
#  ['black',
#   'white',
#   'photo',
#   'live',
#   'room',
#   'larg',
#   'window',
#   'sofa',
#   'chair'],
#  ['greec', 'bond', 'exchang', 'largest', 'debt', 'restructur', 'histori'],
#  ['peopl', 'sit', 'bench', 'front', 'restaur'],
#  ['death', 'toll', 'philippin', 'earthquak', 'rise', 'num'],
#  ['two', 'white', 'dog', 'play', 'brown', 'dog', 'tenni', 'ball'],
#  ['white', 'dog', 'stand', 'fallen', 'leaf'],
#  ['two', 'white', 'dog', 'run', 'togeth'],
#  ['woman', 'put', 'makeup'],
#  ['group', 'peopl', 'gather', 'stand', 'fair'],
#  ['larg',
#   'dog',
#   'small',
#   'dog',
#   'stand',
#   'next',
#   'kitchen',
#   'counter',
#   'investig'],
#  ['man', 'drink', 'orang', 'juic', 'walk', 'sunni', 'day'],
#  ['two', 'boy', 'martial', 'art', 'blue', 'mat'],
#  ['man', 'fri', 'tortilla'],
#  ['child', 'splash', 'pool', 'child', 'kid', 'play', 'background'],
#  ['two', 'cat', 'sit', 'togeth', 'sofa', 'look', 'window'],
#  ['man', 'miss', 'soccer', 'ball'],
#  ['men', 'play', 'soccer'],
#  ['man', 'slice', 'pepper'],
#  ['mdc',
#   'call',
#   'strike',
#   'forc',
#   'mr',
#   'mugab',
#   'either',
#   'resign',
#   'negoti',
#   'settlement',
#   'zimbabw',
#   'crisi'],
#  ['man', 'white', 'moustach', 'stand', 'balconi', 'look', 'road'],
#  ['pennsylvania',
#   'aggress',
#   'treatment',
#   'program',
#   'treat',
#   'num',
#   'num',
#   'inmat'],
#  ['red', 'sox', 'beat', 'tiger', 'num', 'advanc', 'world', 'seri'],
#  ['woman', 'sit', 'near', 'flower', 'bed', 'overlook', 'tunnel'],
#  ['man', 'play', 'drum'],
#  ['man', 'lift', 'weight'],
#  ['human',
#   'right',
#   'violat',
#   'myanmar',
#   'includ',
#   'summari',
#   'execut',
#   'tortur',
#   'recruit',
#   'child',
#   'soldier'],
#  ['girl', 'fall', 'asleep'],
#  ['man', 'skateboard', 'trick', 'park', 'porch'],
#  ['woman', 'dice', 'onion'],
#  ['coupl', 'policewoman', 'sing', 'karaok'],
#  ['red', 'white', 'race', 'car', 'race', 'dirt', 'racetrack'],
#  ['two', 'woman', 'wear', 'bikini', 'walk', 'sand'],
#  ['germani', 'warn', 'greec', 'money', 'without', 'reform'],
#  ['obama', 'condemn', 'egypt', 'violenc', 'cancel', 'militari', 'exercis'],
#  ['thought', 'mostli', 'dutch'],
#  ['irreligion', 'problem'],
#  ['im', 'angri', 'show', 'one', 'scan'],
#  ['hors', 'rider', 'leap', 'barrier'],
#  ['cambodia',
#   'vietnam',
#   'final',
#   'agreement',
#   'stop',
#   'asian',
#   'european',
#   'drug',
#   'traffick'],
#  ['potato', 'slice', 'person'],
#  ['man', 'cut', 'cord', 'sword'],
#  ['prosecutor',
#   'contend',
#   'mr',
#   'durst',
#   'plot',
#   'murder',
#   'assum',
#   'mr',
#   'black',
#   'ident'],
#  ['cat', 'slide', 'upsid', 'couch'],
#  ['small', 'dog', 'walk', 'outsid', 'carri', 'color', 'toy', 'mouth'],
#  ['knight',
#   'agre',
#   'twoyear',
#   'num',
#   'million',
#   'contract',
#   'includ',
#   'num',
#   'sign',
#   'bonu'],
#  ['dog', 'bark', 'ball'],
#  ['man', 'isnt', 'toss', 'kid', 'swim', 'pool', 'near', 'ocean'],
#  ['gener', 'divid', 'gay', 'marriag'],
#  ['two', 'dog', 'run', 'quickli', 'park'],
#  ['isra', 'air', 'strike', 'kill', 'num', 'gaza'],
#  ['surfer', 'black', 'wetsuit', 'ride', 'foami', 'wave'],
#  ['glee',
#   'star',
#   'cori',
#   'monteith',
#   'found',
#   'dead',
#   'hotel',
#   'room',
#   'canada'],
#  ['least', 'num', 'dead', 'northwest', 'iran', 'quak'],
#  ['person', 'peel', 'banana'],
#  ['woman', 'scrape', 'carrot'],
#  ['china', 'mine', 'accid', 'kill', 'num'],
#  ['boy', 'play', 'trampolin'],
#  ['two', 'terrier', 'play', 'wood', 'floor', 'home'],
#  ['perri',
#   'call',
#   'lawmak',
#   'two',
#   'special',
#   'session',
#   'address',
#   'congression',
#   'redistrict'],
#  ['small', 'boy', 'shirt', 'yellow', 'laugh', 'beach'],
#  ['dog', 'black', 'coat', 'run', 'grass', 'tongu', 'hang'],
#  ['bloodi', 'man', 'woman', 'pose', 'pictur'],
#  ['famili', 'pose', 'mantel', 'christma', 'tree'],
#  ['today',
#   'tri',
#   'convey',
#   'problem',
#   'russian',
#   'presid',
#   'vladimir',
#   'putin',
#   'u',
#   'presid',
#   'georg',
#   'w',
#   'bush'],
#  ['man', 'eat', 'banana'],
#  ['man', 'woman', 'two', 'girl', 'walk', 'beach'],
#  ['mud', 'cover', 'topless', 'woman'],
#  ['girl', 'sing', 'stage'],
#  ['woman', 'ad', 'spice', 'meat'],
#  ['orangutan', 'ride', 'bu'],
#  ['problem', 'isnt', 'money'],
#  ['woman', 'handl', 'frog'],
#  ['larg', 'wet', 'yellow', 'dog', 'retriev', 'toy'],
#  ['howev',
#   'decid',
#   'opt',
#   'european',
#   'consortium',
#   'engin',
#   'best',
#   'overal',
#   'solut',
#   'due',
#   'substanti',
#   'price',
#   'effort',
#   'made'],
#  ['shirtless',
#   'man',
#   'escort',
#   'hors',
#   'pull',
#   'carriag',
#   'along',
#   'pave',
#   'road'],
#  ['man', 'dog', 'rocki', 'seashor'],
#  ['origin', 'post', 'jacko'],
#  ['someon', 'bang', 'camera', 'len', 'nail'],
#  ['woman', 'stir', 'egg', 'bowl'],
#  ['man', 'speak', 'stage'],
#  ['woman', 'slice', 'onion', 'knife'],
#  ['meat', 'drop', 'pan'],
#  ['black', 'dog', 'run', 'grass'],
#  ['blue', 'bird', 'perch', 'glove', 'hand', 'person'],
#  ['young', 'boy', 'jump', 'pool', 'outstretch', 'arm'],
#  ['person', 'ride', 'hors'],
#  ['black', 'dog', 'bite', 'light', 'brown', 'dog', 'ear', 'play', 'manner'],
#  ['one', 'man', 'intens', 'play', 'guitar'],
#  ['yellow', 'dog', 'drink', 'water', 'faucet'],
#  ['young', 'woman', 'indian', 'cloth', 'henna', 'hand', 'go', 'paperwork'],
#  ['dog', 'bounc', 'trampolin'],
#  ['woman', 'put', 'cloak', 'larg', 'conceal', 'extravag', 'dress'],
#  ['man', 'snowboard', 'rail', 'snow'],
#  ['three', 'woman', 'run', 'villag'],
#  ['man', 'cut', 'box'],
#  ['girl', 'littl', 'play', 'grand', 'piano', 'stage'],
#  ['convent',
#   'forc',
#   'europ',
#   'treati',
#   'limit',
#   'number',
#   'militari',
#   'aircraft',
#   'tank',
#   'nonnuclear',
#   'heavi',
#   'weapon',
#   'europ'],
#  ['person', 'peel', 'banana'],
#  ['sunday',
#   'u',
#   'soldier',
#   'kill',
#   'anoth',
#   'injur',
#   'southern',
#   'iraq',
#   'munit',
#   'dump',
#   'explod'],
#  ['child', 'two', 'dog', 'play', 'water'],
#  ['new', 'syria', 'opposit', 'chief', 'want', 'nostr', 'aid'],
#  ['two', 'boy', 'martial', 'art', 'blue', 'mat'],
#  ['email', 'oil', 'firm', 'ask', 'trader', 'meet', 'minist'],
#  ['hiker', 'danc', 'top', 'mountain'],
#  ['dog', 'herd', 'group', 'white', 'sheep', 'dusti', 'farm'],
#  ['woman', 'slice', 'potato'],
#  ['navi', 'jet', 'crash', 'apart', 'build'],
#  ['pass',
#   'lemelson',
#   'medic',
#   'educ',
#   'research',
#   'foundat',
#   'limit',
#   'partnership',
#   'num',
#   'syndia'],
#  ['blond', 'girl', 'ride', 'wave'],
#  ['share',
#   'hartford',
#   'rose',
#   'num',
#   'num',
#   'new',
#   'york',
#   'stock',
#   'exchang',
#   'composit',
#   'trade'],
#  ['boy', 'blue', 'shirt', 'dirt', 'face'],
#  ['num',
#   'pm',
#   'edt',
#   'grace',
#   'center',
#   'near',
#   'latitud',
#   'num',
#   'north',
#   'longitud',
#   'num',
#   'west',
#   'num',
#   'mile',
#   'eastsoutheast',
#   'corpu',
#   'christi'],
#  ['woman', 'sit', 'chair', 'christma', 'hold', 'make'],
#  ['dog', 'bark', 'ball'],
#  ['british',
#   'polic',
#   'arrest',
#   'num',
#   'peopl',
#   'earli',
#   'tuesday',
#   'connect',
#   'suspect',
#   'ritual',
#   'murder',
#   'african',
#   'boy',
#   'whose',
#   'torso',
#   'found',
#   'thame',
#   'river'],
#  ['one', 'truck', 'quickli', 'go', 'hill'],
#  ['urg',
#   'congress',
#   'send',
#   'final',
#   'bill',
#   'soon',
#   'possibl',
#   'sign',
#   'law'],
#  ['two', 'woman', 'dog', 'walk', 'forest', 'path'],
#  ['man', 'row', 'boat'],
#  ['black', 'red', 'white', 'pink', 'dress', 'worn', 'woman'],
#  ['block', 'invest'],
#  ['bread', 'slice', 'man'],
#  ['nobodi', 'dangl', 'strap', 'kick'],
#  ['two', 'dog', 'wrestl', 'hug'],
#  ['girl', 'spray', 'plant', 'water'],
#  ['boy', 'blue', 'shirt', 'look', 'hand', 'near', 'stack', 'block', 'tabl'],
#  ['littl', 'girl', 'play', 'piano'],
#  ['protest', 'sweep', 'brazil', 'despit', 'concess'],
#  ['russian', 'foreign', 'ministri', 'state', 'russia', 'suspend', 'dialogu'],
#  ['beauti',
#   'contest',
#   'held',
#   'itali',
#   'next',
#   'week',
#   'may',
#   'first',
#   'pixelperfect',
#   'pinup'],
#  ['man', 'pose', 'watch', 'anoth', 'man'],
#  ['pan', 'drop', 'meat'],
#  ['woman', 'red', 'costum', 'lean', 'brick', 'wall', 'play', 'instrument'],
#  ['small', 'child', 'pink', 'sweater', 'climb', 'concret', 'staircas'],
#  ['muscular',
#   'black',
#   'man',
#   'danc',
#   'man',
#   'behind',
#   'wear',
#   'green',
#   'bead'],
#  ['brown', 'white', 'dog', 'catch', 'dirti', 'tenni', 'ball', 'dirt', 'field'],
#  ['india', 'gangrap', 'victim', 'struggl', 'odd'],
#  ['lustig', 'andrei', 'lyndon', 'johnson', 'john', 'kennedi', 'compat'],
#  ['matt', 'smith', 'leav', 'doctor', 'num', 'year'],
#  ['man', 'play', 'guitar'],
#  ['man', 'play', 'guitar'],
#  ['pictur', 'day', 'num', 'august', 'num'],
#  ['relief', 'boston', 'second', 'suspect', 'captur'],
#  ['typhoon', 'survivor', 'raid', 'philippin', 'store'],
#  ['woman', 'hospit', 'june', 'num', 'kansa', 'health', 'offici', 'said'],
#  ['man', 'danc'],
#  ['woman', 'danc'],
#  ['eu', 'renew', 'sanction', 'zimbabw'],
#  ['one', 'man', 'climb', 'rock', 'wall', 'anoth', 'man', 'hold', 'rope'],
#  ['replac', 'ron', 'dittemor', 'announc', 'resign', 'april', 'num'],
#  ['dog', 'chase', 'ball'],
#  ['numyear',
#   'bond',
#   'usnumytrr',
#   'jump',
#   'num',
#   'take',
#   'yield',
#   'num',
#   'percent',
#   'num',
#   'percent'],
#  ['cat', 'crawl', 'piec', 'furnitur'],
#  ['boy', 'cut', 'grass', 'curb', 'scissor'],
#  ['two', 'team', 'play', 'soccer'],
#  ['num', 'quak', 'strike', 'solomon', 'island'],
#  ['also', 'found', 'short', 'associ', 'famili', 'histori', 'hear', 'loss'],
#  ['sticki', 'goo', 'pull', 'bowl', 'woman'],
#  ['man', 'floor', 'exercis'],
#  ['two', 'brown', 'hors', 'stand', 'grassi', 'field'],
#  ['cancer', 'societi', 'said', 'studi', 'misus'],
#  ['seat', 'woman', 'sing', 'song', 'play', 'guitar'],
#  ['former', 'nazi', 'death', 'camp', 'guard', 'demjanjuk', 'dead', 'num'],
#  ['putin', 'cast', 'ballot', 'russian', 'vote'],
#  ['hair', 'pretti', 'thing', 'tho', 'quot', 'ditto'],
#  ['man', 'stare', 'window'],
#  ['girl', 'color', 'patch', 'cheek'],
#  ['littl', 'child', 'pink', 'sweater', 'climb', 'concret', 'staircas'],
#  ['yellow', 'blue', 'airplan', 'fli', 'sky'],
#  ['larg',
#   'bird',
#   'stand',
#   'tabl',
#   'pick',
#   'plastic',
#   'glass',
#   'contain',
#   'liquid',
#   'place',
#   'bowl',
#   'someth'],
#  ['jewishamerican',
#   'group',
#   'antidefam',
#   'leagu',
#   'adl',
#   'publish',
#   'fullpag',
#   'advertis',
#   'swiss',
#   'intern',
#   'paper',
#   'april',
#   'num',
#   'accus',
#   'switzerland',
#   'fund',
#   'terror',
#   'deal'],
#  ['man', 'blue', 'ride', 'anim', 'dirt', 'road'],
#  ['capit', 'gain', 'top', 'rate', 'percent'],
#  ['man', 'run', 'road'],
#  ['man', 'stand', 'top', 'roof', 'play', 'violin'],
#  ['seven', 'peacekeep', 'kill', 'sudan', 'darfur'],
#  ['fish', 'follow', 'turtl'],
#  ['man', 'shoot', 'shotgun'],
#  ['world', 'news', 'updat', 'need', 'know'],
#  ['man', 'stand', 'besid', 'birdcag', 'larg', 'color'],
#  ['brown', 'dog', 'run', 'snow'],
#  ['furiou', 'racer', 'green', 'grass', 'yell', 'hors', 'jump', 'obstacl'],
#  ['larg', 'dog', 'run', 'grass', 'tenni', 'ball', 'mouth'],
#  ['man', 'put', 'chicken', 'contain'],
#  ['woman', 'take', 'eyeshadow'],
#  ['woman', 'pull', 'sticki', 'goo', 'bowl'],
#  ['boy',
#   'red',
#   'shirt',
#   'front',
#   'long',
#   'blue',
#   'wall',
#   'suspici',
#   'rais',
#   'eyebrow',
#   'camera'],
#  ['black', 'white', 'imag', 'cat', 'lay', 'rug'],
#  ['tent', 'campsit', 'sunlit', 'forest'],
#  ['someon', 'feed', 'anim'],
#  ['tell', 'u', 'charg'],
#  ['woman', 'stage', 'danc'],
#  ['person', 'wear', 'blue', 'shirt', 'walk', 'barefoot', 'tenni', 'court'],
#  ['hors', 'race'],
#  ['cow', 'eat', 'hay'],
#  ['man', 'crouch', 'hold', 'camera'],
#  ['cat', 'run', 'across', 'gravel'],
#  ['tan', 'dog', 'jump', 'catch', 'tenni', 'ball'],
#  ['sea', 'turtl', 'hunt', 'fish'],
#  ['ladi', 'measur', 'ankl', 'anoth', 'woman'],
#  ['black', 'white', 'dog', 'play', 'tatter', 'volleybal', 'brown', 'field'],
#  ['south', 'korean', 'worker', 'start', 'leav', 'joint', 'factori', 'zone'],
#  ['man', 'cowboy', 'hat', 'walk', 'market', 'put', 'hand', 'pocket'],
#  ['man', 'use', 'knife', 'open', 'box'],
#  ['big', 'brown', 'white', 'spot', 'dog', 'lie', 'jacket', 'street'],
#  ['red', 'sox', 'beat', 'tiger', 'reach', 'world', 'seri'],
#  ['one', 'man', 'ride', 'hors'],
#  ['woman', 'wear', 'egyptian', 'headdress'],
#  ['power', 'back', 'state', 'worker', 'head', 'back', 'job', 'friday', 'morn'],
#  ['someon', 'slice', 'veget'],
#  ['read', 'never', 'met', 'anyon', 'proabort'],
#  ['num', 'dead', 'suicid', 'attack', 'yemen', 'polic', 'academi'],
#  ['iran', 'say', 'readi', 'fresh', 'round', 'nuclear', 'talk'],
#  ['cat', 'rub', 'babi', 'face'],
#  ['car', 'bomb', 'kill', 'num', 'damascu'],
#  ['report',
#   'rank',
#   'num',
#   'larg',
#   'compani',
#   'base',
#   'employ',
#   'market',
#   'procur',
#   'commun',
#   'reinvest',
#   'charit',
#   'donat'],
#  ['woman', 'chop', 'octopu'],
#  ['man', 'sang', 'stage', 'microphon'],
#  ['man', 'knife', 'arrest', 'entranc', 'buckingham', 'palac'],
#  ['man', 'think'],
#  ['big', 'group', 'peopl', 'stand', 'two', 'sit', 'couch'],
#  ['num', 'rocket', 'fire', 'gaza', 'southern', 'israel', 'none', 'hurt'],
#  ['hezbollah', 'target', 'qaeda', 'gather', 'along', 'border', 'syria'],
#  ['man', 'break', 'slab', 'concret', 'sledg', 'hammer'],
#  ['two', 'dog', 'play', 'tree'],
#  ['man', 'hat', 'play', 'harp'],
#  ['yellow', 'dog', 'drink', 'water', 'bottl'],
#  ['govern',
#   'bond',
#   'sold',
#   'sharpli',
#   'greenspan',
#   'told',
#   'congress',
#   'tuesday',
#   'u',
#   'economi',
#   'could',
#   'well',
#   'embark',
#   'period',
#   'extend',
#   'growth'],
#  ['nottoosubtl',
#   'swipe',
#   'dean',
#   'predict',
#   'american',
#   'would',
#   'elect',
#   'democrat',
#   'sound',
#   'uncertain',
#   'trumpet',
#   'danger',
#   'time'],
#  ['man', 'absent', 'eat', 'banana', 'tree'],
#  ['man', 'rock', 'high', 'tree', 'stand', 'strang', 'posit'],
#  ['trillionth', 'time', 'ive', 'never', 'said', 'rehabilit', 'doesnt', 'work'],
#  ['ukrain', 'jail', 'opposit', 'icon', 'tymoshenko', 'walk', 'free'],
#  ['boy', 'skateboard', 'metal', 'handrail', 'night'],
#  ['woman', 'boil', 'egg'],
#  ['young', 'gamer', 'play', 'child', 'wear', 'white', 'coat'],
#  ['two', 'men', 'bike', 'side', 'snowi', 'road'],
#  ['person', 'fold', 'squar', 'paper', 'piec'],
#  ['man', 'woman', 'kiss'],
#  ['girl', 'dress', 'purpl', 'blue', 'walk', 'besid', 'bike', 'night'],
#  ['man', 'peel', 'onion'],
#  ['woman', 'cut', 'tomato'],
#  ['kansa',
#   'citi',
#   'draft',
#   'outfield',
#   'chri',
#   'lubanski',
#   'kennedykenrick',
#   'high',
#   'school',
#   'pennsylvania',
#   'fifth',
#   'pick'],
#  ['south', 'africa', 'admit', 'mistak', 'schizophren', 'mandela', 'signer'],
#  ['inadequ',
#   'perform',
#   'student',
#   'variou',
#   'subgroup',
#   'tag',
#   'state',
#   'defici',
#   'feder',
#   'child',
#   'left',
#   'behind',
#   'act'],
#  ['sever', 'dead', 'num', 'injur', 'argentina', 'train', 'crash'],
#  ['nugent', 'complet', 'fool', 'say', 'said'],
#  ['benchmark',
#   'treasuri',
#   'numyear',
#   'note',
#   'gain',
#   'num',
#   'yield',
#   'num',
#   'percent'],
#  ['red', 'cross', 'worker', 'releas', 'ukrain'],
#  ['man', 'open', 'box', 'knife'],
#  ['tan', 'dog', 'dirti', 'roll', 'dirt', 'look', 'right', 'camera'],
#  ['woman', 'break', 'egg'],
#  ['elecia',
#   'battl',
#   'cleveland',
#   'told',
#   'polic',
#   'drop',
#   'purs',
#   'left',
#   'quick',
#   'shop',
#   'food',
#   'mart',
#   'last',
#   'week',
#   'buy',
#   'ticket'],
#  ['small', 'boy', 'stripe', 'shirt', 'slide', 'green', 'tube'],
#  ['investig', 'claim', 'british', 'compani', 'cia', 'cover'],
#  ['peopl', 'flip', 'tire', 'tractor'],
#  ['two', 'child', 'roll', 'clean', 'water'],
#  ['howev',
#   'union',
#   'includ',
#   'power',
#   'cgt',
#   'remain',
#   'oppos',
#   'reform',
#   'demand',
#   'govern',
#   'begin',
#   'fresh',
#   'negoti'],
#  ['man', 'slice', 'garlic', 'put', 'away', 'bread'],
#  ['ukrain', 'leader', 'pledg', 'crisi', 'talk'],
#  ['kevin', 'rudd', 'sworn', 'australian', 'prime', 'minist'],
#  ['two', 'dog', 'play', 'beach'],
#  ['mexican', 'singer', 'jenni', 'rivera', 'believ', 'kill', 'plane', 'crash'],
#  ['boy', 'look', 'calendar'],
#  ['dog', 'bite'],
#  ['doubl', 'decker', 'bu', 'drive', 'citi', 'street'],
#  ['israel', 'free', 'palestinian', 'prison'],
#  ['man', 'play', 'guitar'],
#  ['cat', 'play'],
#  ['child', 'red', 'shirt', 'play', 'leaf'],
#  ['woman', 'stir', 'two', 'egg', 'glass', 'bowl'],
#  ['close', 'small', 'cactu', 'pot'],
#  ['man', 'look', 'comput', 'monitor'],
#  ['dolc', 'gabbana', 'convict', 'tax', 'evas'],
#  ['man', 'play', 'guitar'],
#  ['teenag', 'girl', 'store', 'away', 'bead', 'red'],
#  ['person', 'water', 'beach', 'sun', 'set'],
#  ['man', 'pour', 'oil', 'tomato'],
#  ['woman', 'slice', 'eggplant'],
#  ['girl', 'like', 'red', 'isnt', 'wear', 'bead', 'teenag'],
#  ['woman', 'roll', 'dough'],
#  ['man', 'play', 'guitar'],
#  ['goos', 'flap', 'wing', 'bodi', 'water'],
#  ['one', 'man', 'sit', 'chair'],
#  ['micronesia', 'vice', 'presid', 'visit', 'china'],
#  ['girl', 'fli', 'kite'],
#  ['babi', 'rhino', 'follow', 'adult', 'rhino'],
#  ['dog', 'catch', 'blue', 'ball'],
#  ['two', 'littl', 'boy', 'wear', 'tuxedo'],
#  ['kerri', 'visit', 'jordan', 'israelpalestinian', 'peac', 'agenda'],
#  ['littl', 'girl', 'wear', 'pink', 'shirt', 'play', 'tball', 'take', 'swing'],
#  ['man', 'sentenc', 'num', 'year', 'prison'],
#  ['russian',
#   'offici',
#   'call',
#   'confer',
#   'convent',
#   'forc',
#   'europ',
#   'treati',
#   'discu',
#   'ratif',
#   'amend',
#   'treati'],
#  ['two', 'femal', 'jump', 'swing'],
#  ['ladi', 'break', 'raw', 'egg', 'bowl'],
#  ['dean',
#   'told',
#   'report',
#   'travel',
#   'numciti',
#   'sleepless',
#   'summer',
#   'tour',
#   'consid',
#   'campaign',
#   'texa',
#   'challeng'],
#  ['person', 'peel', 'onion'],
#  ['indict',
#   'said',
#   'attend',
#   'import',
#   'meet',
#   'plan',
#   'attack',
#   'recruit',
#   'fellow',
#   'bomber',
#   'coordin',
#   'oper'],
#  ['swiss', 'tourist', 'gangrap', 'india'],
#  ['he', 'wealthi', 'he', 'success'],
#  ['num', 'aid', 'worker', 'freed', 'oper', 'afghanistan'],
#  ['woman', 'cut', 'shrimp'],
#  ['girl', 'white', 'dress', 'stand'],
#  ['vessel', 'fill', 'mani', 'wonder'],
#  ['doctor', 'help', 'patient'],
#  ['man', 'remov', 'food', 'box'],
#  ['buddha', 'statu', 'sit', 'tabl', 'wooden', 'tabl', 'runner'],
#  ['man', 'sit', 'train', 'rest', 'hand', 'face'],
#  ['nobodi', 'rins', 'steak', 'water'],
#  ['woman', 'peel', 'potato'],
#  ['man', 'ride', 'hors', 'creek'],
#  ['white',
#   'cat',
#   'perch',
#   'small',
#   'wooden',
#   'cabinet',
#   'look',
#   'outsid',
#   'window'],
#  ['center',
#   'presid',
#   'joseph',
#   'torsella',
#   'struck',
#   'head',
#   'abl',
#   'walk',
#   'ambul'],
#  ['woman', 'play', 'game', 'man'],
#  ['three', 'men', 'danc'],
#  ['bald', 'man', 'touch', 'nose', 'black', 'hors', 'side', 'fenc'],
#  ['blue', 'orang', 'airplan', 'fli', 'land', 'gear'],
#  ['man', 'hold', 'frog'],
#  ['captain',
#   'robert',
#   'ramsey',
#   'u',
#   'numst',
#   'armour',
#   'divis',
#   'said',
#   'truck',
#   'explod',
#   'outsid',
#   'build',
#   'numam',
#   'one',
#   'compound',
#   'outer',
#   'wall',
#   'collaps'],
#  ['person', 'tear', 'paper'],
#  ['asian', 'market', 'mix', 'china', 'trade', 'data'],
#  ['woman', 'put', 'makeup', 'man'],
#  ['u', 'up', 'pressur', 'israel', 'un', 'demand', 'gaza', 'truce'],
#  ['man', 'write', 'book'],
#  ['dog', 'excitedli', 'play', 'water', 'grass'],
#  ['group', 'peopl', 'sit', 'around', 'tabl', 'food'],
#  ['east', 'harlem', 'explos', 'death', 'toll', 'rise'],
#  ['person', 'wear', 'jean', 'sit', 'happili', 'top', 'hors', 'saddl'],
#  ['man', 'kite', 'surf', 'away', 'camera'],
#  ['man', 'set', 'fire', 'nation', 'mall', 'dy', 'injuri'],
#  ['white', 'tan', 'dog', 'run', 'tall', 'green', 'grass'],
#  ['man', 'danc', 'ceil', 'room'],
#  ['blue', 'motorcycl', 'park', 'sidewalk'],
#  ['squirrel', 'spin', 'around', 'circl'],
#  ['lion', 'pace', 'tiredli', 'pen'],
#  ['child', 'wear', 'black', 'tight', 'hop'],
#  ['two', 'found', 'dead', 'swim', 'pool', 'essex', 'hotel'],
#  ['closeup', 'brown', 'hors', 'head'],
#  ['man', 'lean', 'pole', 'surround', 'peopl'],
#  ['asian', 'woman', 'crowd', 'carri', 'black', 'bag'],
#  ['dog', 'walk', 'along', 'snowdrift'],
#  ['dog', 'sleep', 'green', 'grass'],
#  ['man', 'talk', 'phone'],
#  ['man', 'sit', 'comfort', 'tabl'],
#  ['nato', 'regret', 'russia', 'decis', 'suspend', 'particip', 'cfe'],
#  ['man', 'move', 'tree', 'limb'],
#  ['shirtless',
#   'man',
#   'stripe',
#   'short',
#   'sunglass',
#   'stand',
#   'near',
#   'person',
#   'white',
#   'shirt',
#   'sunglass'],
#  ['woman', 'put', 'makeup', 'care'],
#  ['man', 'talk', 'cell', 'phone'],
#  ['man', 'glass', 'talk'],
#  ['spokeswoman',
#   'strong',
#   'memori',
#   'hospit',
#   'said',
#   'doud',
#   'satisfactori',
#   'condit',
#   'tuesday',
#   'night'],
#  ['three', 'cow', 'graze', 'grassi', 'field'],
#  ['orang', 'kitten', 'lay', 'leather', 'couch'],
#  ['woman', 'care', 'debon', 'fish'],
#  ['man', 'make', 'phone', 'call'],
#  ['man', 'wildli', 'danc'],
#  ['ehud',
#   'olmert',
#   'former',
#   'isra',
#   'prime',
#   'minist',
#   'sentenc',
#   'six',
#   'year',
#   'jail',
#   'corrupt'],
#  ['man', 'run', 'jump', 'kick', 'near', 'vend', 'machin'],
#  ['three', 'child', 'run', 'grassi', 'hillsid'],
#  ['five', 'peopl', 'stand', 'grass', 'three', 'dog'],
#  ['guitar', 'play', 'man'],
#  ['two', 'larg', 'dog', 'frolick', 'grassi', 'field'],
#  ['person', 'play', 'soccer', 'kick', 'ball', 'goal'],
#  ['woman', 'water', 'ski', 'lake'],
#  ['surfer', 'black', 'wetsuit', 'ride', 'foami', 'wave'],
#  ['train', 'sit', 'track', 'near', 'field'],
#  ['person', 'drop', 'chop', 'veget', 'pot', 'stove'],
#  ['two', 'dog', 'play', 'grass'],
#  ['man',
#   'full',
#   'gear',
#   'wear',
#   'helmet',
#   'sponsor',
#   'logo',
#   'ride',
#   'red',
#   'sport',
#   'motorcycl'],
#  ['person', 'stir', 'veget', 'pot'],
#  ['num', 'democrat', 'assembl', 'num', 'republican'],
#  ['woman', 'put', 'lemon'],
#  ['jim',
#   'william',
#   'director',
#   'usvisit',
#   'project',
#   'said',
#   'middl',
#   'novemb',
#   'mani',
#   'arriv',
#   'passeng',
#   'atlanta',
#   'fingerprint',
#   'photograph'],
#  ['european',
#   'union',
#   'ban',
#   'import',
#   'genet',
#   'modifi',
#   'food',
#   'num',
#   'unit',
#   'state',
#   'demand',
#   'eu',
#   'end',
#   'ban'],
#  ['young', 'boy', 'play', 'park', 'mother'],
#  ['part', 'deal', 'mr', 'delainey', 'agre', 'cooper', 'continu', 'investig'],
#  ['child', 'wake'],
#  ['boy', 'play', 'piano'],
#  ['woman', 'eat'],
#  ['chapman', 'immedi', 'arrest', 'expect', 'appear', 'arraign', 'juli', 'num'],
#  ['man', 'helmet', 'paint', 'red', 'ride', 'blue', 'motorcycl', 'road'],
#  ['man', 'put', 'trumpet', 'away'],
#  ['brown', 'white', 'dog', 'run', 'river'],
#  ['nobodi', 'sit', 'chair', 'watch', 'ocean'],
#  ['group', 'child', 'church', 'basement', 'play', 'maraca', 'tambourin'],
#  ['skier', 'black', 'catch', 'tini', 'bit', 'air'],
#  ['man', 'jump', 'rope', 'outsid'],
#  ['dog', 'catch', 'blue', 'ball'],
#  ['dog', 'swim', 'tenni', 'ball'],
#  ['dog', 'bark', 'noisili'],
#  ['person', 'cut', 'garlic', 'piec', 'knife'],
#  ['renown', 'spanish', 'flamenco', 'guitarist', 'paco', 'de', 'lucia', 'dy'],
#  ['small', 'white', 'dog', 'run', 'across', 'lawn'],
#  ['man', 'knock', 'hors'],
#  ['u', 'senat', 'meet', 'path', 'fiscal', 'impass', 'still', 'elus'],
#  ['moham', 'morsi', 'sworn', 'eygptian', 'presid'],
#  ['group', 'hors', 'graze', 'field'],
#  ['russia',
#   'threaten',
#   'sever',
#   'time',
#   'withdraw',
#   'cfe',
#   'odd',
#   'unit',
#   'state',
#   'u',
#   'plan',
#   'instal',
#   'missil',
#   'defens',
#   'shield',
#   'eastern'],
#  ['syrian', 'war', 'seen', 'drag', 'year'],
#  ['footbal', 'player', 'carri', 'offici', 'past', 'roll', 'footbal'],
#  ['old', 'man', 'black', 'trench', 'coat', 'stand', 'marketplac'],
#  ['british',
#   'foreign',
#   'offic',
#   'said',
#   'monday',
#   'coalit',
#   'author',
#   'iraq',
#   'pleas',
#   'men',
#   'freed'],
#  ['boy', 'young', 'age', 'play', 'park', 'mother'],
#  ['woman', 'swim'],
#  ['muscular', 'man', 'danc', 'man', 'behind', 'wear', 'green', 'bead'],
#  ['four', 'young', 'men', 'explod', 'car', 'stand', 'still', 'behind'],
#  ['babi', 'rhino', 'follow', 'adult', 'rhino'],
#  ['someon', 'play', 'piano'],
#  ['babi', 'laugh'],
#  ['dog', 'brown', 'jump', 'air'],
#  ['woman', 'pencil', 'eyeshadow'],
#  ['man', 'pour', 'pot', 'chees', 'sauc', 'shred', 'plate'],
#  ['girl',
#   'orang',
#   'shirt',
#   'clown',
#   'makeup',
#   'walk',
#   'park',
#   'other',
#   'look'],
#  ['palestinian',
#   'num',
#   'gaza',
#   'milit',
#   'kill',
#   'isra',
#   'airstrik',
#   'coastal',
#   'strip'],
#  ['live', 'room', 'tabl', 'chair', 'sofa', 'alongsid', 'larg', 'palm'],
#  ['audi', 'buy', 'motorcycl', 'maker', 'ducati'],
#  ['judg', 'ok', 'forcefeed', 'california', 'inmat'],
#  ['broader',
#   'standard',
#   'poor',
#   'num',
#   'index',
#   'spx',
#   'climb',
#   'num',
#   'point',
#   'num',
#   'percent',
#   'num'],
#  ['dog', 'backyard', 'carri', 'black', 'fur', 'basket', 'mouth'],
#  ['two', 'child', 'adult', 'stand', 'next', 'tree', 'limb'],
#  ['two', 'child', 'hang', 'larg', 'branch'],
#  ['cat', 'play', 'watermelon'],
#  ['remov',
#   'site',
#   'list',
#   'broken',
#   'english',
#   'rule',
#   'hacker',
#   'might',
#   'particip'],
#  ['man', 'open', 'packag', 'contain', 'headphon'],
#  ['rouhani', 'lead', 'iran', 'presidenti', 'vote', 'preliminari', 'result'],
#  ['littl', 'girl', 'pink', 'shirt', 'play', 'tball', 'take', 'swing'],
#  ['two', 'car', 'race', 'road', 'front', 'grassi', 'park', 'area'],
#  ['woman', 'put', 'eyeshadow'],
#  ['tini', 'blond', 'child', 'blue', 'dress', 'sit', 'tabl', 'near', 'mother'],
#  ['woman', 'pick'],
#  ['woman',
#   'wear',
#   'red',
#   'jacket',
#   'hold',
#   'glass',
#   'front',
#   'man',
#   'white',
#   'tshirt'],
#  ['man', 'play', 'acoust', 'guitar'],
#  ['small', 'child', 'show', 'excit', 'swing', 'set', 'park'],
#  ['young', 'girl', 'back', 'flip', 'water'],
#  ['person', 'slice', 'onion'],
#  ['crowd', 'watch', 'footbal', 'game'],
#  ['man', 'exercis'],
#  ['pak', 'mission', 'uae', 'gear', 'elect'],
#  ['man', 'walk', 'hors'],
#  ['white', 'plane', 'runway'],
#  ['iran', 'condemn', 'alleg', 'isra', 'airstrik', 'syria'],
#  ['boy', 'teen', 'isnt', 'talk', 'girl', 'webcam'],
#  ['num', 'milit', 'kill', 'afghan', 'raid', 'offici'],
#  ['woman', 'walk', 'dog', 'street'],
#  ['pedestrian', 'car', 'move', 'traffic', 'jam', 'big', 'citi'],
#  ['brown', 'black', 'dog', 'look', 'upward'],
#  ['clown', 'sing', 'peopl', 'danc'],
#  ['banana', 'peel', 'person'],
#  ['countri', 'oppos', 'weapon', 'space', 'arm', 'race', 'space'],
#  ['young', 'boy', 'sing', 'play', 'guitar'],
#  ['two', 'dog', 'play', 'beach'],
#  ['woman', 'cut', 'carrot'],
#  ['ladi', 'isnt', 'slice', 'meat'],
#  ['iguaran',
#   'state',
#   'detaine',
#   'accus',
#   'homicid',
#   'crimin',
#   'collabor',
#   'kidnap',
#   'fund',
#   'terror'],
#  ['titan', 'violin', 'nab', 'record', 'num', 'million'],
#  ['dog', 'jump', 'trampolin'],
#  ['obama', 'nomin', 'new', 'transport', 'secretari'],
#  ['china', 'give', 'u', 'regul', 'access', 'audit', 'record'],
#  ['american', 'footbal', 'wear', 'red', 'white', 'strip'],
#  ['young', 'man', 'woman', 'ride', 'bike', 'boardwalk', 'near', 'ocean'],
#  ['man', 'jersey', 'dunk', 'ball', 'basketbal', 'game'],
#  ['man', 'ride', 'hors'],
#  ['man', 'walk', 'along', 'track', 'wilder'],
#  ['motocross', 'rider', 'wear', 'blue', 'black', 'pant'],
#  ['person',
#   'red',
#   'hood',
#   'jacket',
#   'black',
#   'backpack',
#   'walk',
#   'near',
#   'rocki',
#   'wall'],
#  ['man', 'carv', 'hole', 'piec', 'wood'],
#  ['philippin', 'typhoon', 'death', 'toll', 'num', 'un'],
#  ['man', 'cut', 'tomato', 'piec'],
#  ['man', 'type', 'machin', 'use', 'stenographi'],
#  ['man', 'trick', 'bike'],
#  ['sever', 'peopl', 'front', 'color', 'build'],
#  ['bubbl', 'blew', 'dye', 'girl', 'shirt', 'red'],
#  ['german', 'parliament', 'overwhelmingli', 'back', 'greek', 'rescu', 'deal'],
#  ['syria', 'rebel', 'attack', 'lebanes', 'post', 'near', 'border', 'armi'],
#  ['guitar', 'play', 'man'],
#  ['person',
#   'back',
#   'pack',
#   'topless',
#   'front',
#   'pile',
#   'rock',
#   'cloud',
#   'background'],
#  ['u', 'attorney', 'gener', 'holder', 'resign'],
#  ['vietnam', 'detect', 'signal', 'miss', 'plane'],
#  ['valu',
#   'total',
#   'num',
#   'million',
#   'includ',
#   'convert',
#   'secur',
#   'accord',
#   'corel'],
#  ['plane', 'fli', 'distanc'],
#  ['two', 'boy', 'talk', 'phone'],
#  ['man', 'lift', 'heavi', 'weight'],
#  ['woman', 'slice', 'potato'],
#  ['young', 'boy', 'jump', 'air', 'knee', 'bent', 'arm', 'spread'],
#  ['two', 'child', 'small', 'play', 'toy', 'car', 'street'],
#  ['footbal', 'player', 'red', 'white', 'uniform', 'lift', 'two', 'teammat'],
#  ['boy', 'blue', 'coveral', 'paint'],
#  ['iran', 'exclud', 'syria', 'peac', 'talk', 'un'],
#  ['blond',
#   'girl',
#   'pink',
#   'top',
#   'smile',
#   'wear',
#   'funni',
#   'glass',
#   'larg',
#   'nose',
#   'attach'],
#  ['man', 'blue', 'shirt', 'stand', 'front', 'fountain'],
#  ['two', 'littl', 'boy', 'play', 'outsid', 'soccer', 'ball', 'green', 'grass'],
#  ['two', 'construct', 'worker', 'sit', 'side', 'palac'],
#  ['man', 'hungrili', 'eat', 'bowl', 'cereal'],
#  ['person', 'bike', 'air', 'near', 'bodi', 'water'],
#  ['woman', 'slice', 'onion'],
#  ['bride', 'black', 'veil', 'look'],
#  ['girl', 'run', 'along', 'river', 'bank', 'two', 'black', 'dog'],
#  ['skier', 'white', 'catch', 'tini', 'bit', 'air'],
#  ['neg', 'reconnaiss', 'requir'],
#  ['russia', 'say', 'ballist', 'missil', 'fire', 'mediterranean'],
#  ['white', 'fluffi', 'dog', 'run', 'pure', 'white', 'snow'],
#  ['church',
#   'member',
#   'observ',
#   'say',
#   'expect',
#   'decis',
#   'could',
#   'problemat',
#   'mani',
#   'episcopalian'],
#  ['aveng', 'set', 'box', 'offic', 'record'],
#  ['bone', 'fragment', 'could', 'king', 'alfr'],
#  ['two', 'boy', 'couch', 'play', 'video', 'game'],
#  ['walker', 'hat', 'store', 'men'],
#  ['pa',
#   'bill',
#   'big',
#   'brother',
#   'watch',
#   'said',
#   'rep',
#   'john',
#   'mabri',
#   'dwaco'],
#  ['piano', 'play', 'someon'],
#  ['boy', 'play', 'guitar'],
#  ['china', 'stock', 'open', 'flat', 'monday'],
#  ['cameron', 'concern', 'halal', 'meat'],
#  ['man', 'purpl', 'suit', 'stand', 'purpl', 'case', 'play', 'guitar'],
#  ['pier', 'morgan', 'question', 'polic'],
#  ['group', 'four', 'brown', 'dog', 'play', 'field', 'brown', 'grass'],
#  ['woman', 'slice', 'onion'],
#  ['antiputin', 'protest', 'form', 'human', 'chain', 'moscow'],
#  ['two', 'peopl', 'snow', 'wear', 'cloth', 'provid', 'camouflag'],
#  ['cat', 'stuck', 'ceil', 'fan', 'move'],
#  ['crowd', 'watch', 'two', 'car', 'design', 'race', 'leav', 'start', 'line'],
#  ['soni', 'xperia', 'znum', 'nokiaäô', 'x', 'seri', 'unveil'],
#  ['two', 'peopl', 'two', 'chair', 'read', 'pleasantli'],
#  ['dog', 'stand', 'side', 'mountain'],
#  ['young', 'girl', 'pink', 'shirt', 'peac', 'lie', 'grass'],
#  ['deer', 'jump', 'fenc'],
#  ['three', 'child', 'run', 'grassi', 'hillsid'],
#  ['zen', 'report', 'aint', 'easi', 'high', 'mainten'],
#  ['nobodi', 'slice', 'piec', 'bread'],
#  ['man', 'play', 'skull'],
#  ['estonian',
#   'offici',
#   'state',
#   'cyber',
#   'attack',
#   'caus',
#   'estonian',
#   'govern',
#   'websit',
#   'shut',
#   'temporarili',
#   'came',
#   'comput',
#   'administr',
#   'russia',
#   'includ',
#   'offic',
#   'presid',
#   'vladimir',
#   'putin'],
#  ['woman', 'fri', 'someth'],
#  ['coupl', 'sit', 'patio', 'look', 'ocean'],
#  ['american', 'footbal', 'wear', 'red', 'white', 'strip'],
#  ['person', 'ride', 'motorbik', 'sandi', 'track'],
#  ['man', 'cut', 'potato'],
#  ['woman', 'danc', 'sing', 'alon'],
#  ['bangkok', 'tens', 'thai', 'elect', 'eve'],
#  ['child', 'red', 'outfit', 'jump', 'trampolin'],
#  ['imran', 'contest', 'four', 'na', 'seat'],
#  ['syria', 'journalist', 'rescu', 'bid', 'fail'],
#  ['man', 'play', 'guitar'],
#  ['young', 'girl', 'blue', 'fun', 'slide'],
#  ['boy', 'stripe', 'shirt', 'play', 'front', 'water', 'fountain'],
#  ['two', 'cow', 'stand', 'larg', 'field'],
#  ['tirana', 'capit'],
#  ['man', 'miss', 'soccer', 'ball'],
#  ['man',
#   'yellow',
#   'sport',
#   'bike',
#   'wheeli',
#   'friend',
#   'black',
#   'bike',
#   'catch'],
#  ['man', 'talk'],
#  ['woman', 'slice', 'tomato'],
#  ['man', 'talk', 'woman', 'seat', 'besid', 'drive', 'car'],
#  ['white', 'bird', 'land', 'swiftli', 'water'],
#  ['man', 'stand', 'sidewalk'],
#  ['romanian', 'presid', 'declar', 'victori'],
#  ['rabbi', 'talk'],
#  ['girl', 'uniform', 'blue', 'quickli', 'rais', 'arm'],
#  ['person', 'set', 'fire', 'camera'],
#  ['greek', 'pm', 'announc', 'new', 'elect'],
#  ['man', 'speak', 'podium'],
#  ['white',
#   'cat',
#   'perch',
#   'small',
#   'wooden',
#   'cabinet',
#   'look',
#   'outsid',
#   'window'],
#  ['ukrain', 'nine', 'peopl', 'die', 'kyiv', 'clash'],
#  ['man', 'play', 'guitar'],
#  ['man', 'particip', 'bmx', 'race'],
#  ['woman', 'fri', 'someth', 'pan'],
#  ['dog', 'play', 'field', 'brown', 'grass'],
#  ['aust', 'share', 'num', 'interest', 'rate', 'cut'],
#  ['young', 'orient', 'girl', 'stand', 'crowd', 'play', 'pinwheel'],
#  ['person', 'put', 'salt', 'pepper', 'piec', 'pork'],
#  ['man', 'draw', 'figur'],
#  ['woman', 'place', 'two', 'egg', 'pot', 'water'],
#  ['man', 'lunch'],
#  ['man', 'sing', 'play', 'guitar'],
#  ['man', 'danc'],
#  ['hors', 'race'],
#  ['girl', 'carri', 'sign', 'group', 'peopl', 'follow'],
#  ['man', 'cut', 'grass'],
#  ['man', 'sing', 'play', 'guitar'],
#  ['ahmad',
#   'fight',
#   'extradit',
#   'unit',
#   'state',
#   'lodg',
#   'formal',
#   'complaint',
#   'alleg',
#   'british',
#   'polic',
#   'concoct',
#   'intellig',
#   'report',
#   'implic',
#   'ahmad',
#   'terror',
#   'activ',
#   'desecr',
#   'koran'],
#  ['woman', 'slice', 'octopu'],
#  ['num', 'kill', 'sever', 'injur', 'sw', 'china', 'car', 'accid'],
#  ['boy', 'stand', 'front', 'car', 'burn'],
#  ['brown', 'puppi', 'gnaw', 'metal', 'post', 'stuck', 'ground'],
#  ['china', 'nuclear', 'power', 'member', 'un', 'secur', 'council'],
#  ['charli', 'rangel', 'censur', 'anyon', 'see', 'footag'],
#  ['two', 'kenyan', 'minist', 'among', 'num', 'kill', 'plane', 'crash'],
#  ['iran', 'up', 'oil', 'swap', 'eastern', 'neighbor'],
#  ['guitar', 'play', 'man'],
#  ['left', 'armi', 'syria', 'receiv', 'religi', 'train'],
#  ['share', 'move', 'higher', 'wall', 'street'],
#  ['sheik',
#   'doon',
#   'salad',
#   'ilmi',
#   'said',
#   'civilian',
#   'casualti',
#   'result',
#   'overnight',
#   'mortar',
#   'rocket',
#   'attack',
#   'happen',
#   'everi',
#   'day'],
#  ['siemen',
#   'spokesman',
#   'germani',
#   'state',
#   'heinrich',
#   'von',
#   'pierer',
#   'state',
#   'siemen',
#   'begin',
#   'talk',
#   'interest',
#   'chines',
#   'parti',
#   'sale',
#   'plutoniumprocess',
#   'facil'],
#  ['car', 'move', 'road'],
#  ['person', 'quickli', 'chop', 'mushroom', 'knife'],
#  ['three', 'woman', 'sit', 'togeth', 'near', 'woven', 'wall'],
#  ['black', 'white', 'dog', 'run', 'field'],
#  ['woman', 'poke', 'potato'],
#  ['blond', 'girl', 'hang', 'gymnast', 'rope'],
#  ['man', 'drive', 'car'],
#  ['man', 'jump', 'rope', 'field'],
#  ['man', 'talk', 'woman'],
#  ['boy', 'climb', 'wall', 'artifici', 'built', 'climb', 'attach', 'rope'],
#  ['syria', 'urg', 'refuge', 'return'],
#  ['brown', 'white', 'dog', 'move', 'wild', 'grass'],
#  ['boy', 'crawl', 'dog', 'hous'],
#  ['cyclist', 'make', 'bike', 'jump', 'two', 'rock'],
#  ['saudil', 'airstrik', 'hit', 'yemeni', 'capit'],
#  ['woman', 'ride', 'seadoo'],
#  ['young', 'girl', 'stand', 'one', 'leg'],
#  ['texan',
#   'saddl',
#   'skyrocket',
#   'homeown',
#   'premium',
#   'might',
#   'final',
#   'get',
#   'relief'],
#  ['egg', 'strongli', 'whisk', 'bowl', 'person'],
#  ['beard', 'man', 'stand', 'shop', 'cart', 'hold', 'cardboard', 'sign'],
#  ['man', 'slice', 'potato'],
#  ['two',
#   'larg',
#   'dog',
#   'light',
#   'color',
#   'one',
#   'dark',
#   'one',
#   'quickli',
#   'move',
#   'snowi',
#   'terrain'],
#  ['person', 'wear', 'hat', 'sit', 'grass'],
#  ['rider', 'blue', 'black', 'motocross', 'bike', 'wear', 'pant'],
#  ['man', 'perform', 'jump', 'bicycl'],
#  ['group', 'peopl', 'walk', 'street', 'person', 'green', 'hat', 'phone'],
#  ['three', 'woman', 'danc'],
#  ['man', 'speak', 'phone'],
#  ['woman', 'slice', 'onion'],
#  ['hrithik', 'roshan', 'wife', 'sussann', 'part', 'way'],
#  ['person', 'pour', 'oliv', 'oil', 'pot', 'stove'],
#  ['myanmar',
#   'world',
#   'largest',
#   'produc',
#   'illeg',
#   'opium',
#   'limit',
#   'financi',
#   'technic',
#   'resourc',
#   'end',
#   'drug',
#   'trade'],
#  ['man', 'run'],
#  ['chicago', 'shoot', 'show', 'gap', 'steppedup', 'polic'],
#  ['indian', 'armi', 'kill', 'num', 'milit', 'indiancontrol', 'kashmir'],
#  ['black', 'dog', 'emerg', 'water', 'white', 'ball', 'mouth'],
#  ['one', 'climb', 'grotto', 'pink', 'interior'],
#  ['one', 'small', 'child', 'drink', 'water', 'cup'],
#  ['person', 'slice', 'bread', 'piec'],
#  ['result',
#   'murphi',
#   'sought',
#   'substitut',
#   'strier',
#   'sister',
#   'ethel',
#   'celnik',
#   'truste'],
#  ['black', 'dog', 'run', 'across', 'rocki', 'landscap'],
#  ['revenu', 'rose', 'num', 'percent', 'num', 'billion', 'num', 'billion'],
#  ['woman', 'ride', 'hors'],
#  ['woman', 'peel', 'potato'],
#  ['swimmer', 'race', 'lake'],
#  ['woman', 'cut', 'flower'],
#  ['man', 'purpl', 'hat', 'isnt', 'climb', 'rocki', 'wall', 'bare', 'hand'],
#  ['ice', 'skate', 'rink', 'place', 'outdoor', 'empti'],
#  ['barefoot',
#   'man',
#   'pajama',
#   'look',
#   'toward',
#   'sky',
#   'walk',
#   'tenni',
#   'court'],
#  ['four', 'girl', 'backbend', 'play', 'outdoor'],
#  ['potato', 'slice', 'woman'],
#  ['man', 'ride', 'hors'],
#  ['caus', 'whitney', 'houston', 'death', 'could', 'take', 'week'],
#  ['chef', 'care', 'pour', 'oil', 'pan'],
#  ['puppi', 'repeatedli', 'roll', 'side', 'side', 'back'],
#  ['dozen', 'kill', 'air', 'strike', 'bakeri', 'central', 'syria'],
#  ['philip', 'leaf', 'hospit', 'num', 'day'],
#  ['person', 'ride', 'bike', 'along', 'muddi', 'trail'],
#  ['man', 'slowli', 'fold', 'tortilla'],
#  ['rock', 'band', 'plane', 'make', 'emerg', 'land', 'ill'],
#  ['man', 'remov', 'carrot', 'machin'],
#  ['grey', 'white', 'domest', 'kitten', 'lie', 'desk'],
#  ['cat', 'lick', 'sucker'],
#  ['woman', 'slice', 'garlic'],
#  ['man',
#   'brown',
#   'hair',
#   'wear',
#   'sunglass',
#   'sit',
#   'listlessli',
#   'tabl',
#   'can',
#   'soda',
#   'drink'],
#  ['thought', 'mostli', 'dutch'],
#  ['dog', 'jump', 'high', 'air', 'countri'],
#  ['heavi', 'fight', 'rock', 'eastern', 'syria', 'ahead', 'poll'],
#  ['two', 'dog', 'play', 'insid'],
#  ['person', 'squeez', 'open', 'rock', 'face'],
#  ['spokesman',
#   'fbi',
#   'cia',
#   'canadian',
#   'secur',
#   'intellig',
#   'servic',
#   'royal',
#   'canadian',
#   'mount',
#   'polic',
#   'declin',
#   'comment',
#   'el',
#   'shukrijumah',
#   'stay',
#   'canada'],
#  ['two', 'cat', 'play', 'fight'],
#  ['poll', 'open', 'russian', 'presidenti', 'elect'],
#  ['egypt', 'policeman', 'kill', 'sinai', 'attack'],
#  ['taiwan', 'rattl', 'strong', 'earthquak'],
#  ['shirtless', 'man', 'sat', 'chair'],
#  ['backyard', 'light', 'play', 'trick', 'dark', 'brown', 'black', 'dog'],
#  ['one', 'man', 'two', 'woman', 'dress', 'vampir', 'costum'],
#  ['man', 'slice', 'veget'],
#  ['climber', 'stand', 'rock', 'face', 'next', 'pink', 'rope'],
#  ['child', 'play', 'front', 'larg', 'door'],
#  ['someon', 'pour', 'ingredi', 'pot'],
#  ['glove', 'said', 'unifi', 'offici', 'rob', 'oneil'],
#  ['boy', 'wear', 'white', 'hat', 'run', 'beach'],
#  ['man', 'catch', 'fish'],
#  ['two', 'differ', 'breed', 'brown', 'white', 'dog', 'play', 'beach'],
#  ['mean', 'believ', 'word', 'mainstream', 'medium'],
#  ['shirtless',
#   'man',
#   'escort',
#   'hors',
#   'pull',
#   'carriag',
#   'along',
#   'pave',
#   'road'],
#  ['man', 'play', 'keyboard'],
#  ['man', 'play', 'drum'],
#  ['orang', 'rescu', 'boat', 'rush', 'across', 'water'],
#  ['boy', 'play', 'trumpet'],
#  ['white', 'dog', 'run', 'across', 'rocki', 'landscap'],
#  ['child', 'play', 'water', 'spout', 'outdoor', 'rest', 'famili', 'watch'],
#  ['olivia', 'colman', 'win', 'second', 'bafta', 'award'],
#  ['david', 'beckham', 'retir', 'end', 'season'],
#  ['young', 'boy', 'jump', 'cover', 'nearbi', 'wooden', 'fenc', 'grass'],
#  ['north',
#   'korean',
#   'govern',
#   'warn',
#   'south',
#   'korean',
#   'govern',
#   'particip',
#   'prolifer',
#   'secur',
#   'initi',
#   'program'],
#  ['usain', 'bolt', 'win', 'numm', 'steven', 'howard', 'reaction'],
#  ['man', 'play', 'guitar'],
#  ['algerian', 'govern', 'parti', 'domin', 'elect'],
#  ['herd', 'carib', 'cross', 'road'],
#  ['bieng', 'unaccpt'],
#  ['druce', 'face', 'murder', 'charg', 'cont', 'said'],
#  ['bodi', 'found', 'sever', 'week', 'later', 'green', 'river'],
#  ['dog', 'roll', 'ground'],
#  ['dog', 'run', 'toward', 'ball'],
#  ['isra',
#   'forc',
#   'arrest',
#   'num',
#   'palestinian',
#   'overnight',
#   'clash',
#   'local'],
#  ['big', 'brown', 'white', 'spot', 'dog', 'lie', 'cloth', 'street'],
#  ['one', 'person', 'ride', 'bicycl', 'sand', 'besid', 'ocean'],
#  ['polic', 'arrest', 'num', 'honduran', 'drug', 'traffick', 'suspect'],
#  ['content', 'bowl', 'mix', 'man'],
#  ['dog', 'golden', 'coat', 'swim', 'water'],
#  ['child', 'hold', 'camera', 'front', 'face'],
#  ['man', 'danger', 'throw', 'knife', 'tree'],
#  ['red', 'doubl', 'decker', 'bu', 'take', 'passeng'],
#  ['white',
#   'dog',
#   'wear',
#   'christma',
#   'reindeer',
#   'headband',
#   'play',
#   'brown',
#   'dog',
#   'grass'],
#  ['moscow',
#   'crimea',
#   'success',
#   'could',
#   'lead',
#   'redraw',
#   'ukrain',
#   'eastern',
#   'border'],
#  ['man', 'shoot', 'shotgun'],
#  ['notif', 'first', 'report', 'friday', 'msnbc'],
#  ['man', 'play', 'piano', 'nose'],
#  ['woman', 'put', 'cosmet', 'eyelid'],
#  ['cat', 'play', 'piano'],
#  ['nato', 'stick', 'transit', 'roadmap', 'afghanistan', 'rasmussen'],
#  ['washington', 'pot', 'shop', 'prepar', 'histor', 'sale'],
#  ['south', 'korea', 'report', 'seven', 'new', 'mer', 'case'],
#  ['train', 'run', 'track'],
#  ['iraqi',
#   'polic',
#   'open',
#   'fire',
#   'downtown',
#   'baghdad',
#   'today',
#   'demonstr',
#   'storm',
#   'polic',
#   'station',
#   'demand',
#   'given',
#   'job',
#   'claim',
#   'paid',
#   'bribe'],
#  ['revenu',
#   'hulk',
#   'came',
#   'well',
#   'last',
#   'month',
#   'marvel',
#   'comic',
#   'adapt',
#   'xnum',
#   'xmen',
#   'unit',
#   'gross',
#   'num',
#   'million',
#   'open',
#   'weekend'],
#  ['valid',
#   'signatur',
#   'num',
#   'regist',
#   'california',
#   'voter',
#   'must',
#   'collect',
#   'turn',
#   'counti',
#   'elect',
#   'offici',
#   'sept',
#   'num'],
#  ['babi', 'laugh', 'crawl'],
#  ['bunch', 'cell'],
#  ['man', 'woman', 'talk'],
#  ['three', 'boy', 'jump', 'leaf'],
#  ['find',
#   'appear',
#   'wednesday',
#   'journal',
#   'american',
#   'medic',
#   'associ',
#   'news',
#   'web',
#   'site'],
#  ['cold', 'cyclist', 'celebr'],
#  ['two', 'dog', 'share', 'toy', 'field', 'veget'],
#  ['woman', 'cut', 'veget'],
#  ['yahoo',
#   'account',
#   'num',
#   'bsd',
#   'site',
#   'num',
#   'nttverio',
#   'num',
#   'infospac',
#   'survey',
#   'found'],
#  ['man', 'swing', 'rope', 'attach', 'ceil'],
#  ['brown', 'dog', 'jump', 'air'],
#  ['technologylac',
#   'nasdaq',
#   'composit',
#   'index',
#   'ixic',
#   'ad',
#   'num',
#   'point',
#   'num',
#   'percent',
#   'num'],
#  ['group', 'peopl', 'danc', 'concert'],
#  ['peopl', 'sing'],
#  ['dog', 'run', 'backyard', 'full', 'leaf'],
#  ['kid', 'play', 'soccer', 'field'],
#  ['defens',
#   'chief',
#   'estonia',
#   'latvia',
#   'lithuania',
#   'germani',
#   'itali',
#   'spain',
#   'slovakia',
#   'sign',
#   'agreement',
#   'provid',
#   'staff',
#   'fund',
#   'center'],
#  ['surfer', 'ride', 'big', 'wave', 'across', 'dark', 'green', 'water'],
#  ['peopl', 'ride', 'paddl', 'raft'],
#  ['man', 'woman', 'talk', 'diner'],
#  ['man', 'rock', 'climb', 'citi', 'bay', 'background'],
#  ['person', 'hold', 'net', 'stand', 'water'],
#  ['black', 'sheep', 'stand', 'near', 'three', 'white', 'dog'],
#  ['gener',
#   'nikolai',
#   'n',
#   'urakov',
#   'state',
#   'telephon',
#   'state',
#   'scientif',
#   'center',
#   'appli',
#   'microbiolog',
#   'quit',
#   'reliabl',
#   'system',
#   'protect',
#   'case',
#   'emerg'],
#  ['least', 'num', 'dead', 'somalia', 'attack'],
#  ['man', 'slice', 'potato'],
#  ['white', 'bird', 'swiftli', 'take', 'water'],
#  ['girl', 'uniform', 'play', 'flute', 'march', 'band'],
#  ['poll', 'close', 'egyptian', 'presidenti', 'elect'],
#  ['chines', 'presid', 'meet', 'indian', 'vice', 'presid'],
#  ['man', 'row', 'boat'],
#  ['man', 'woman', 'eat'],
#  ['man', 'water', 'grass', 'excitedli', 'play', 'dog'],
#  ['lawyer',
#   'michael',
#   'karra',
#   'name',
#   's',
#   'dhillon',
#   'could',
#   'reach',
#   'comment'],
#  ['blitzbokk', 'oust', 'fiji'],
#  ['person', 'cut', 'burrata', 'chees'],
#  ['ice', 'skate', 'rink', 'place', 'outdoor', 'full', 'peopl'],
#  ['obama', 'declar', 'health', 'care', 'law', 'work'],
#  ['group', 'footbal', 'player', 'run', 'field'],
#  ['two', 'dog', 'play', 'shore'],
#  ['two', 'kid', 'play', 'swim', 'pool', 'green', 'color', 'crocodil', 'float'],
#  ['move',
#   'u',
#   'lot',
#   'closer',
#   'say',
#   'foam',
#   'kind',
#   'damag',
#   'said',
#   'hubbard',
#   'member',
#   'columbia',
#   'accid',
#   'investig',
#   'board'],
#  ['woman', 'ride', 'hors'],
#  ['two', 'woman', 'dress', 'white', 'black', 'relax', 'bench'],
#  ['cfe', 'treati', 'sign', 'num'],
#  ['man', 'play', 'trumpet'],
#  ['woman', 'dress', 'green', 'play', 'tan', 'dog'],
#  ['state',
#   'scientif',
#   'center',
#   'appli',
#   'microbiolog',
#   'everi',
#   'kind',
#   'deadli',
#   'bacteria',
#   'studi',
#   'use',
#   'secret',
#   'biolog',
#   'weapon',
#   'program',
#   'soviet',
#   'union'],
#  ['woman', 'slice', 'tomato'],
#  ['holland', 'threaten', 'legal', 'action', 'affair', 'alleg'],
#  ['classroom',
#   'full',
#   'student',
#   'look',
#   'direct',
#   'insid',
#   'bamboo',
#   'structur'],
#  ['protest', 'continu', 'tens', 'ukrain', 'capit'],
#  ['also',
#   'give',
#   'microsoft',
#   'opportun',
#   'comment',
#   'remedi',
#   'propos',
#   'commiss'],
#  ['woman', 'slice', 'tomato'],
#  ['paper', 'say', 'may', 'num', 'num'],
#  ['pair', 'kid', 'stick', 'blue', 'green', 'color', 'tongu'],
#  ['holland', 'win', 'french', 'presidenti', 'elect'],
#  ['gunner', 'fire', 'fail', 'advanc', 'champion', 'leagu'],
#  ['toyland', 'johnni', 'mathi', 'vessel', 'fill', 'mani', 'wonder'],
#  ['num', 'kill', 'hot', 'lava', 'indonesia', 'volcano', 'erupt'],
#  ['three', 'boy', 'karat', 'costum', 'fight'],
#  ['blond', 'ladi', 'look', 'tower'],
#  ['dog', 'snap', 'droplet', 'water'],
#  ['dog', 'lie', 'back', 'wooden', 'floor'],
#  ['young', 'boy', 'climb', 'wall', 'made', 'rock'],
#  ['toni', 'abbott', 'sworn', 'new', 'australian', 'pm'],
#  ['man', 'slice', 'tape', 'box'],
#  ['coron', 'street', 'bill', 'roach', 'arrest'],
#  ['china',
#   'health',
#   'ministri',
#   'said',
#   'five',
#   'peopl',
#   'die',
#   'sar',
#   'num',
#   'infect'],
#  ['child', 'hold', 'camera', 'front', 'face'],
#  ['person', 'stand', 'vast', 'field', 'glacial', 'ice'],
#  ['boy', 'check', 'calendar'],
#  ['man', 'play', 'wooden', 'flute'],
#  ['woman', 'ride', 'water', 'scooter'],
#  ['small', 'dog', 'chase', 'larg', 'brown', 'cow'],
#  ['man', 'slice', 'cucumb', 'knife'],
#  ['chines', 'news', 'agenc', 'slam', 'delay', 'search', 'jet'],
#  ['hurdl', 'leapt', 'hors', 'rider', 'back'],
#  ['woman', 'slice', 'eggplant'],
#  ['boy', 'play', 'guitar'],
#  ['steam', 'engin', 'train', 'move', 'toward', 'camera'],
#  ['dog', 'golden', 'coat', 'walk', 'water'],
#  ['five', 'peopl', 'stand', 'grass', 'three', 'dog'],
#  ['weiner', 'stay', 'nyc', 'mayor', 'race', 'amid', 'new', 'sext', 'scandal'],
#  ['french', 'retire', 'increas', 'one', 'fifth', 'third', 'popul', 'num'],
#  ['man', 'make', 'bed', 'hotel'],
#  ['gang', 'isnt', 'crime'],
#  ['two', 'peopl', 'sit', 'park', 'bench', 'sunni', 'day'],
#  ['bradley', 'triumph', 'fireston', 'furyk', 'fade'],
#  ['man',
#   'yellow',
#   'sport',
#   'bike',
#   'wheeli',
#   'friend',
#   'black',
#   'bike',
#   'catch'],
#  ['man', 'pushup', 'wall'],
#  ['two', 'peopl', 'look', 'statu', 'made', 'gold'],
#  ['peopl', 'float', 'raft'],
#  ['lugar', 'nunn', 'senat'],
#  ['badger', 'burrow', 'hole'],
#  ['person', 'dice', 'pepper', 'orang'],
#  ['bride', 'white', 'dress', 'look'],
#  ['boy', 'happili', 'play', 'piano'],
#  ['person', 'play', 'piano'],
#  ['romney', 'win', 'florida', 'republican', 'primari'],
#  ['blond', 'boy', 'slide', 'dune', 'sand', 'skateboard'],
#  ['black', 'white', 'cow', 'hay'],
#  ['group', 'peopl', 'sit', 'dim', 'room'],
#  ['man', 'play', 'video', 'game', 'store'],
#  ['group', 'peopl', 'sit', 'dim', 'room'],
#  ['cheerlead', 'take', 'break'],
#  ['myanmar',
#   'militari',
#   'ruler',
#   'burn',
#   'approxim',
#   'num',
#   'million',
#   'dollar',
#   'worth',
#   'illeg',
#   'drug',
#   'mark',
#   'intern',
#   'day',
#   'drug',
#   'abus',
#   'illicit',
#   'traffick'],
#  ['runner', 'race', 'track'],
#  ['black', 'dog', 'run', 'across', 'rocki', 'landscap'],
#  ['babi', 'lick', 'dog'],
#  ['bangladesh', 'islamist', 'ralli', 'atheist', 'blogger'],
#  ['man',
#   'wear',
#   'cloth',
#   'cover',
#   'paint',
#   'sit',
#   'outsid',
#   'busi',
#   'area',
#   'write',
#   'someth'],
#  ['boy', 'lay', 'couch', 'dog'],
#  ['kitchen', 'sink', 'countertop', 'bowl', 'shelf'],
#  ['group', 'peopl', 'hold', 'food', 'point', 'camera'],
#  ['child', 'delightedli', 'play', 'toy', 'outdoor'],
#  ['woman', 'walk', 'dog'],
#  ['man', 'clumsili', 'kick', 'box', 'trainer'],
#  ['young', 'girl', 'blue', 'leotard', 'jump', 'air'],
#  ['man', 'isnt', 'intens', 'play', 'guitar'],
#  ['u',
#   'special',
#   'forc',
#   'troop',
#   'train',
#   'colombian',
#   'soldier',
#   'militari',
#   'base',
#   'region',
#   'protect',
#   'pipelin',
#   'transport',
#   'crude',
#   'colombia',
#   'secondbiggest',
#   'oil',
#   'field'],
#  ['umm', 'pretti', 'clearli', 'state', 'statut', 'presum', 'constitut'],
#  ['woman', 'cook', 'egg'],
#  ['happi', 'famili', 'pose', 'fireplac'],
#  ['flute', 'play', 'man'],
#  ['havent',
#   'decid',
#   'whether',
#   'use',
#   'unbroken',
#   'dot',
#   'white',
#   'line',
#   'experi',
#   'worth',
#   'introduc',
#   'said',
#   'david',
#   'richardson',
#   'icc',
#   'cricket',
#   'manag'],
#  ['donna', 'summer', 'queen', 'disco', 'dy', 'num'],
#  ['bishop', 'armidal', 'peter', 'brain', 'forthright'],
#  ['nato', 'soldier', 'kill', 'afghan', 'attack'],
#  ['man', 'sit', 'grass', 'drink', 'water', 'bottl'],
#  ['num', 'kill', 'shrine', 'bomb', 'northwest', 'pakistan'],
#  ['glover',
#   'said',
#   'killer',
#   'use',
#   'peculiar',
#   'slipknot',
#   'ligatur',
#   'use',
#   'strangl',
#   'victim'],
#  ['bride', 'groom', 'arriv', 'wed'],
#  ['li', 'na', 'announc', 'retir'],
#  ['man', 'sing', 'woman'],
#  ['woman', 'ride', 'hors'],
#  ['nypd', 'twitter', 'outreach', 'backfir', 'badli'],
#  ['white', 'dog', 'run', 'field', 'yellow', 'flower'],
#  ['man', 'isnt', 'cautious', 'feed', 'mous', 'snake'],
#  ['peopl', 'beach', 'full', 'sand', 'ocean', 'enjoy', 'sunni', 'day'],
#  ['peopl', 'look', 'costum', 'gather', 'vicin', 'forest'],
#  ['iaea', 'report', 'restrict'],
#  ['larg', 'brown', 'dog', 'jump', 'red', 'hurdl'],
#  ['man', 'read', 'email'],
#  ['skier', 'wear', 'blue', 'snow', 'pant', 'fli', 'air', 'near', 'jump'],
#  ['teenag', 'girl', 'wear', 'bead', 'red'],
#  ['russia',
#   'would',
#   'immedi',
#   'increas',
#   'militari',
#   'strength',
#   'along',
#   'russian',
#   'border'],
#  ['mr', 'alibek', 'said', 'outcom', 'encourag'],
#  ['electr', 'energi', 'come', 'batteri'],
#  ['man', 'ride', 'hors'],
#  ['talent', 'man', 'play', 'guitar'],
#  ['googl', 'name', 'new', 'motorola', 'mobil', 'ceo'],
#  ['mandela', 'releas', 'hospit'],
#  ['ladi', 'slice', 'meat'],
#  ['woman', 'danc', 'cage'],
#  ['woman', 'cut', 'onion'],
#  ['child', 'chase', 'sand'],
#  ['thought', 'movi', 'good', 'didnt', 'find', 'confus', 'way'],
#  ['protest', 'u', 'drone', 'strike', 'pak', 'postpon'],
#  ['clown', 'sing', 'peopl', 'danc'],
#  ['late',
#   'afternoon',
#   'dow',
#   'jone',
#   'industri',
#   'averag',
#   'num',
#   'num',
#   'percent',
#   'num',
#   'gain',
#   'num',
#   'point',
#   'monday',
#   'highest',
#   'level',
#   'sinc',
#   'juli',
#   'num'],
#  ['man', 'draw', 'pictur'],
#  ['man', 'play', 'piano'],
#  ['two', 'peopl', 'snow', 'wear', 'cloth', 'provid', 'camouflag'],
#  ['man', 'play', 'larg', 'flute'],
#  ['woman', 'march', 'pair', 'dog'],
#  ['man', 'sing', 'play', 'guitar'],
#  ['philippin', 'quak', 'death', 'toll', 'climb', 'num'],
#  ['instrument', 'play', 'band'],
#  ['produc', 'noth', 'eat', 'wear', 'live'],
#  ['woman', 'slice', 'pepper', 'green'],
#  ['cook', 'slice', 'bell', 'pepper'],
#  ['owe', 'dollar', 'problem'],
#  ['butter', 'chop', 'contain', 'man'],
#  ['prolifer',
#   'secur',
#   'initi',
#   'call',
#   'stop',
#   'search',
#   'ship',
#   'suspect',
#   'carri',
#   'weapon',
#   'mass',
#   'destruct'],
#  ['u', 'delay', 'missil', 'test', 'tension', 'rise'],
#  ['man', 'purpl', 'hat', 'climb', 'rocki', 'wall', 'bare', 'hand'],
#  ['man', 'load', 'weapon', 'bullet'],
#  ['clinton', 'testifi', 'month', 'benghazi', 'attack'],
#  ['kim', 'jongun', 'execut', 'wors', 'dog', 'uncl'],
#  ['dog', 'golden', 'coat', 'swim', 'water'],
#  ['panda', 'climb'],
#  ['news',
#   'terror',
#   'israelipalestinian',
#   'conflict',
#   'januari',
#   'num',
#   'äď',
#   'num',
#   'num'],
#  ['pair', 'kid', 'stick', 'blue', 'green', 'color', 'tongu'],
#  ['black', 'orang', 'bird', 'stand', 'lawn'],
#  ['syrian', 'rebel', 'move', 'command', 'turkey', 'syria'],
#  ['man', 'play', 'water'],
#  ['man', 'escap', 'rise', 'swamp'],
#  ['woman', 'slice', 'cucumb'],
#  ['came',
#   'basic',
#   'washington',
#   'establish',
#   'relationship',
#   'make',
#   'sure',
#   'get',
#   'feder',
#   'money',
#   'california',
#   'schwarzenegg',
#   'said',
#   'meet',
#   'congression',
#   'republican'],
#  ['man', 'play', 'harp'],
#  ['billion', 'everyon', 'world', 'mexico', 'current', 'prosper', 'level'],
#  ['brown', 'white', 'cat', 'jump', 'sidewalk'],
#  ['man', 'cut', 'paper'],
#  ['india', 'ink', 'imag', 'day', 'april', 'num'],
#  ['forex', 'amp', 'gold', 'num', 'august', 'num'],
#  ['china', 'high', 'alert', 'typhoon', 'kalmaegi'],
#  ['herd', 'carib', 'cross', 'road', 'quickli'],
#  ['person', 'ride', 'motorbik', 'event', 'relat', 'motocross'],
#  ['isra',
#   'soldier',
#   'knock',
#   'empti',
#   'mobil',
#   'home',
#   'water',
#   'tower',
#   'num',
#   'tini',
#   'west',
#   'bank',
#   'settlement',
#   'outpost',
#   'overnight',
#   'part',
#   'usback',
#   'mideast',
#   'peac',
#   'plan'],
#  ['cat', 'play', 'keyboard'],
#  ['closeup', 'sheep', 'tongu', 'hang'],
#  ['arthur',
#   'benson',
#   'attorney',
#   'case',
#   'plaintiff',
#   'schoolchildren',
#   'said',
#   'appeal'],
#  ['dog', 'brown', 'jump', 'air'],
#  ['woman', 'run', 'beach', 'dog', 'leash'],
#  ['black', 'white', 'dog', 'hold', 'basebal', 'mouth'],
#  ['dog', 'eat', 'doll'],
#  ['child', 'arent', 'play', 'front', 'larg', 'door'],
#  ['toddler', 'make', 'splash', 'insid', 'blue', 'paddl', 'pool'],
#  ['man', 'black', 'wetsuit', 'ride', 'foami', 'wave'],
#  ['black', 'white', 'dog', 'play', 'tatter', 'volleybal', 'brown', 'field'],
#  ['compani',
#   'highlight',
#   'addit',
#   'net',
#   'jnume',
#   'support',
#   'enterpris',
#   'applic',
#   'environ',
#   'eae',
#   'new',
#   'mainfram'],
#  ['mexican',
#   'govern',
#   'adopt',
#   'seri',
#   'measur',
#   'drug',
#   'traffick',
#   'organ',
#   'crime',
#   'within',
#   'mexico',
#   'sinc',
#   'num'],
#  ['three', 'men', 'sit', 'mountainsid', 'look', 'view', 'pair', 'binocular'],
#  ['luzern',
#   'counti',
#   'district',
#   'attorney',
#   'david',
#   'lupa',
#   'told',
#   'news',
#   'confer',
#   'monday',
#   'author',
#   'continu',
#   'make',
#   'signific',
#   'progress',
#   'case'],
#  ['policeman', 'sit', 'motorcycl'],
#  ['girl', 'blue', 'slide', 'green', 'slide'],
#  ['militari', 'offic', 'bark', 'recruit'],
#  ['nicaragua',
#   'commemor',
#   'numth',
#   'anniversari',
#   'sandinista',
#   'revolut',
#   'toppl',
#   'dictatorship',
#   'anastasio',
#   'somoza',
#   'impos',
#   'cubanstyl',
#   'leftist',
#   'regim'],
#  ['jet', 'fli'],
#  ['soccer', 'ball', 'roll', 'goal', 'net'],
#  ['aggrav', 'situat'],
#  ['woman', 'waterski'],
#  ['headlight', 'blue', 'car'],
#  ['quy', 'doan', 'spokesman', 'vietnames', 'ministri', 'cultur', 'inform'],
#  ['sever', 'boy', 'jump', 'trampolin'],
#  ['man', 'woman', 'walk', 'street', 'citi'],
#  ['girl', 'hit', 'littl', 'tee', 'basebal'],
#  ['man', 'show', 'small', 'monkey'],
#  ['helicopt', 'crash', 'near', 'rail', 'station', 'london'],
#  ['earli',
#   'may',
#   'num',
#   'offici',
#   'philippin',
#   'malaysia',
#   'indonesia',
#   'sign',
#   'antiterror',
#   'agreement',
#   'share',
#   'airlin',
#   'passeng',
#   'list',
#   'intellig'],
#  ['britain', 'reach', 'syria', 'opposit'],
#  ['man', 'play', 'flute'],
#  ['whitey', 'bulger', 'given', 'two', 'consecut', 'life', 'term'],
#  ['hors', 'ridden', 'girl'],
#  ['man', 'cut', 'fish'],
#  ['woman', 'ad', 'spice', 'meat'],
#  ['toy', 'train', 'miss', 'toy', 'car'],
#  ['sever', 'young', 'peopl', 'pose', 'photo', 'hold', 'beer'],
#  ['young', 'boy', 'play', 'park', 'mother'],
#  ['girl', 'blue', 'white', 'uniform', 'cheer'],
#  ['student', 'take', 'ride', 'airwav'],
#  ['xma', 'cruis', 'passeng', 'hit', 'noroviru'],
#  ['man', 'jersey', 'dunk', 'ball', 'basketbal', 'game'],
#  ['current', 'ridden', 'group', 'friend', 'raft'],
#  ['plan',
#   'tunisia',
#   'creation',
#   'electron',
#   'databas',
#   'facilit',
#   'tax',
#   'collect'],
#  ['thai', 'opposit', 'parti', 'boycott', 'gener', 'elect'],
#  ['threejudg',
#   'panel',
#   'numth',
#   'u',
#   'circuit',
#   'court',
#   'appeal',
#   'rule',
#   'late',
#   'friday',
#   'small',
#   'size',
#   'limit',
#   'use',
#   'secular',
#   'purpos',
#   'make',
#   'imag',
#   'legitim'],
#  ['two', 'peopl', 'snowsuit', 'lie', 'snow', 'make', 'snow', 'angel'],
#  ['girl', 'slice', 'butter', 'two', 'piec'],
#  ['boy', 'play', 'noodl', 'pool'],
#  ['young', 'gamer', 'play', 'child', 'wear', 'white', 'coat'],
#  ['someon', 'slice', 'tomato'],
#  ['today', 'histori', 'dec', 'num'],
#  ['man', 'play', 'guitar'],
#  ['lacey', 'welcom', 'back'],
#  ['person', 'slice', 'potato'],
#  ['gillett',
#   'share',
#   'rose',
#   'num',
#   'num',
#   'percent',
#   'num',
#   'afternoon',
#   'new',
#   'york',
#   'stock',
#   'exchang',
#   'trade'],
#  ['cluster', 'four', 'brown', 'dog', 'play', 'field', 'brown', 'grass'],
#  ['islam', 'state', 'issu', 'video', 'behead', 'u', 'hostag'],
#  ['woman', 'ad', 'sauc', 'food'],
#  ['woman', 'slice', 'butter'],
#  ['middl', 'eastern', 'man', 'stand', 'back', 'lamp', 'post', 'near', 'peopl'],
#  ['woman', 'cut', 'squash'],
#  ['pass',
#   'num',
#   'never',
#   'put',
#   'effect',
#   'law',
#   'would',
#   'made',
#   'illeg',
#   'bar',
#   'restaur',
#   'patron',
#   'light'],
#  ['question', 'need', 'ask'],
#  ['mani', 'execut', 'iran', 'hang', 'public'],
#  ['girl', 'blue', 'white', 'uniform', 'isnt', 'cheer'],
#  ['veget', 'put', 'pot', 'man'],
#  ...]

# %%
documents = []
for idx, sent in enumerate(total_sents_unk):
    documents.append(TaggedDocument(sent, [idx]))

# %%
model = Doc2Vec(documents, vector_size=25, window=6, min_count=1, workers=1, epochs=30, alpha=0.1, min_alpha=0.001, hs=1)

# %%
model.random.seed(42)
train_data['s1'] = train_data['s1'].apply(lambda x: model.infer_vector(x))
train_data['s2'] = train_data['s2'].apply(lambda x: model.infer_vector(x))

# %%
y_pred = train_data.apply(lambda x: (1 - spatial.distance.cosine(x['s1'], x['s2'])+1)/2, axis=1)
y_train = train_data['score']
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.47

# %%
val_data['s1'] = val_data['s1'].apply(lambda x: model.infer_vector(x))
val_data['s2'] = val_data['s2'].apply(lambda x: model.infer_vector(x))

# %%
y_pred = val_data.apply(lambda x: (1 - spatial.distance.cosine(x['s1'], x['s2'])+1)/2, axis=1)
y_train = val_data['score']
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.56

# %%
test_data['s1'] = test_data['s1'].apply(lambda x: model.infer_vector(x))
test_data['s2'] = test_data['s2'].apply(lambda x: model.infer_vector(x))

# %%
y_pred = test_data.apply(lambda x: ((1 - spatial.distance.cosine(x['s1'], x['s2']))+1)*2.5, axis=1)
y_train = test_data['score']
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.47

# %% [markdown]
# ### BiLSTM Model

# %%
train_embeddings1 = torch.Tensor(list(train_data['s1']))
train_embeddings2 = torch.Tensor(list(train_data['s2']))
train_score = torch.Tensor(list(train_data['score']))

val_embeddings1 = torch.Tensor(list(val_data['s1']))
val_embeddings2 = torch.Tensor(list(val_data['s2']))
val_score = torch.Tensor(list(val_data['score']))

test_embeddings1 = torch.Tensor(list(test_data['s1']))
test_embeddings2 = torch.Tensor(list(test_data['s2']))
test_score = torch.Tensor(list(test_data['score']))

# %%
input_dim = 25
hidden_dim = 25
lr = 0.001
num_epochs = 10
batch_size = 10

# %%
class BiLSTMRegression(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.bilstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim*2, 1)

    def forward(self, x1, x2):
        x = torch.cat((x1, x2), dim=1)
        x = x.view(len(x), 1, -1)
        h0 = torch.zeros(self.num_layers*2, len(x), self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers*2, len(x), self.hidden_dim).to(x.device)
        out, _ = self.bilstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %%
model = BiLSTMRegression(input_dim*2, hidden_dim, num_layers=2)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = nn.MSELoss()

class SentenceSimilarityDataset(data.Dataset):
    def __init__(self, embeddings1, embeddings2, scores):
        self.embeddings1 = embeddings1
        self.embeddings2 = embeddings2
        self.scores = scores

    def __len__(self):
        return len(self.embeddings1)

    def __getitem__(self, index):
        return self.embeddings1[index], self.embeddings2[index], self.scores[index]
    
train_dataset = SentenceSimilarityDataset(train_embeddings1, train_embeddings2, train_score)
val_dataset = SentenceSimilarityDataset(val_embeddings1, val_embeddings2, val_score)

train_dataloader = data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)


for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for batch in train_dataloader:
        optimizer.zero_grad()
        embeddings1_batch, embeddings2_batch, scores_batch = batch
        output = model(embeddings1_batch, embeddings2_batch)
        loss = criterion(output.squeeze(), scores_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * len(embeddings1_batch)
    train_loss /= len(train_embeddings1)

    val_loss = 0
    with torch.no_grad():
        for batch in val_dataloader:
            embeddings1_batch, embeddings2_batch, scores_batch = batch
            val_output = model(embeddings1_batch, embeddings2_batch)
            val_loss += criterion(val_output.squeeze(), scores_batch).item() * len(embeddings1_batch)
    val_loss /= len(val_embeddings1)

    print(f"Epoch = {epoch}\tTraining Loss = {train_loss}\tValidation Loss = {val_loss}")
# Out:
# Epoch = 0	Training Loss = 0.07198671058086226	Validation Loss = 0.0752607791886463
# Epoch = 1	Training Loss = 0.05243354639869979	Validation Loss = 0.0716338195199785
# Epoch = 2	Training Loss = 0.046353306964072895	Validation Loss = 0.06969077409883323
# Epoch = 3	Training Loss = 0.04230629820090699	Validation Loss = 0.07281764294590697
# Epoch = 4	Training Loss = 0.03813186941010449	Validation Loss = 0.07748702112129414
# Epoch = 5	Training Loss = 0.035115631875488204	Validation Loss = 0.08006021806358041
# Epoch = 6	Training Loss = 0.0326171828130736	Validation Loss = 0.08548914877554545
# Epoch = 7	Training Loss = 0.030110111669932996	Validation Loss = 0.08600907015835645
# Epoch = 8	Training Loss = 0.028265988875324468	Validation Loss = 0.08848732217928147
# Epoch = 9	Training Loss = 0.026940590660268108	Validation Loss = 0.08746444982300688

# %%
model.eval()
output = model(train_embeddings1, train_embeddings2)
y_pred = output.squeeze().tolist()
y_train = train_score
corr = pearson_corr(y_train, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.82

# %%
model.eval()
output = model(val_embeddings1, val_embeddings2)
y_pred = output.squeeze().tolist()
y_val = val_score
corr = pearson_corr(y_val, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.41

# %%
model.eval()
output = model(test_embeddings1, test_embeddings2)
y_pred = output.squeeze().tolist()
y_test = test_score
corr = pearson_corr(y_test, y_pred)
print("Pearson correlation coefficient: {:.2f}".format(corr))
# Out:
# Pearson correlation coefficient: 0.41

# %%
df_raw = pd.read_csv('../../train.csv')
id = df_raw['id'].values
s1_raw = df_raw['s1'].values
s2_raw = df_raw['s2'].values
y_raw = df_raw['score'].values

model.eval()
with torch.no_grad():
    print(len(train_embeddings1))
    output = model(train_embeddings1, train_embeddings2)
    y_pred = output.squeeze()
    # y_pred = model(s1_train, s2_train)
    # y_pred = y_pred.numpy()
    # y_pred = np.squeeze(y_pred)
    # y_pred = np.clip(y_pred, 0, 5)
    print(id.shape, s1_raw.shape, y_raw.shape, len(y_pred))
    results = pd.DataFrame({'id': id, 'sentence1': s1_raw, 'sentence2': s2_raw, 'similarity': y_raw, 'predicted_similarity': y_pred})
    results.to_csv(f'Results/train.csv', index=False)
    print(f'Predictions saved in results.csv')

correlation = pd.Series(y_raw).corr(pd.Series(y_pred))
print('Correlation between expected and predicted similarity scores:', correlation)
# Out:
# 12833
# (12833,) (12833,) (12833,) 12833
# Predictions saved in results.csv
# Correlation between expected and predicted similarity scores: 0.8204012146124229

# %%
df_raw = pd.read_csv('../../test.csv')
id = df_raw['id'].values
s1_raw = df_raw['s1'].values
s2_raw = df_raw['s2'].values
y_raw = df_raw['score'].values

model.eval()
with torch.no_grad():
    output = model(test_embeddings1, test_embeddings2)
    y_pred = output.squeeze()
    # y_pred = model(s1_train, s2_train)
    # y_pred = y_pred.numpy()
    # y_pred = np.squeeze(y_pred)
    # y_pred = np.clip(y_pred, 0, 5)
    print(id.shape, s1_raw.shape, y_raw.shape, len(y_pred))
    results = pd.DataFrame({'id': id, 'sentence1': s1_raw, 'sentence2': s2_raw, 'similarity': y_raw, 'predicted_similarity': y_pred})
    results.to_csv(f'Results/test.csv', index=False)
    print(f'Predictions saved in results.csv')

correlation = pd.Series(y_raw).corr(pd.Series(y_pred))
print('Correlation between expected and predicted similarity scores:', correlation)
# Out:
# (3347,) (3347,) (3347,) 3347
# Predictions saved in results.csv
# Correlation between expected and predicted similarity scores: 0.4123440842953832
